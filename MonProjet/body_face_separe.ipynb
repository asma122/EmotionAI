# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#      10 image.flags.writeable = False
#      12 # Make Detections
# ---> 13 results = holistic.process(image)
#      14 # print(results.face_landmarks)
#      15
#      16 # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
#      17
#      18 # Recolor image back to BGR for rendering
#      19 image.flags.writeable = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
# ...

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
num_coords2 = len(results.left_hand_landmarks.landmark)+len(results.right_hand_landmarks.landmark)
num_coords2
# Out:
# 42

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val)]

# %%
landmarks2 = ['class']
for val in range(1, num_coords2+1):
    landmarks2 += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'x2',
#  'y2',
#  'z2',
#  'x3',
#  'y3',
#  'z3',
#  'x4',
#  'y4',
#  'z4',
#  'x5',
#  'y5',
#  'z5',
#  'x6',
#  'y6',
#  'z6',
#  'x7',
#  'y7',
#  'z7',
#  'x8',
#  'y8',
#  'z8',
#  'x9',
#  'y9',
#  'z9',
#  'x10',
#  'y10',
#  'z10',
#  'x11',
#  'y11',
#  'z11',
#  'x12',
#  'y12',
#  'z12',
#  'x13',
#  'y13',
#  'z13',
#  'x14',
#  'y14',
#  'z14',
#  'x15',
#  'y15',
#  'z15',
#  'x16',
#  'y16',
#  'z16',
#  'x17',
#  'y17',
#  'z17',
#  'x18',
#  'y18',
#  'z18',
#  'x19',
#  'y19',
#  'z19',
#  'x20',
#  'y20',
#  'z20',
#  'x21',
#  'y21',
#  'z21',
#  'x22',
#  'y22',
#  'z22',
#  'x23',
#  'y23',
#  'z23',
#  'x24',
#  'y24',
#  'z24',
#  'x25',
#  'y25',
#  'z25',
#  'x26',
#  'y26',
#  'z26',
#  'x27',
#  'y27',
#  'z27',
#  'x28',
#  'y28',
#  'z28',
#  'x29',
#  'y29',
#  'z29',
#  'x30',
#  'y30',
#  'z30',
#  'x31',
#  'y31',
#  'z31',
#  'x32',
#  'y32',
#  'z32',
#  'x33',
#  'y33',
#  'z33',
#  'x34',
#  'y34',
# ...

# %%
landmarks2
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'x2',
#  'y2',
#  'z2',
#  'x3',
#  'y3',
#  'z3',
#  'x4',
#  'y4',
#  'z4',
#  'x5',
#  'y5',
#  'z5',
#  'x6',
#  'y6',
#  'z6',
#  'x7',
#  'y7',
#  'z7',
#  'x8',
#  'y8',
#  'z8',
#  'x9',
#  'y9',
#  'z9',
#  'x10',
#  'y10',
#  'z10',
#  'x11',
#  'y11',
#  'z11',
#  'x12',
#  'y12',
#  'z12',
#  'x13',
#  'y13',
#  'z13',
#  'x14',
#  'y14',
#  'z14',
#  'x15',
#  'y15',
#  'z15',
#  'x16',
#  'y16',
#  'z16',
#  'x17',
#  'y17',
#  'z17',
#  'x18',
#  'y18',
#  'z18',
#  'x19',
#  'y19',
#  'z19',
#  'x20',
#  'y20',
#  'z20',
#  'x21',
#  'y21',
#  'z21',
#  'x22',
#  'y22',
#  'z22',
#  'x23',
#  'y23',
#  'z23',
#  'x24',
#  'y24',
#  'z24',
#  'x25',
#  'y25',
#  'z25',
#  'x26',
#  'y26',
#  'z26',
#  'x27',
#  'y27',
#  'z27',
#  'x28',
#  'y28',
#  'z28',
#  'x29',
#  'y29',
#  'z29',
#  'x30',
#  'y30',
#  'z30',
#  'x31',
#  'y31',
#  'z31',
#  'x32',
#  'y32',
#  'z32',
#  'x33',
#  'y33',
#  'z33',
#  'x34',
#  'y34',
# ...

# %%
with open('najlafaceneutre.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
with open('najlahandsneutre.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks2)

# %%
class_name = "neutral"

# %%
cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw landmarks on the image
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1))
        
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))

        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))

        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

        try:
            # Check if all landmarks are present
            if (results.pose_landmarks and results.face_landmarks and
                results.right_hand_landmarks and results.left_hand_landmarks):

                # Extract Pose landmarks
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                
                # Extract Face landmarks
                face = results.face_landmarks.landmark
                face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
                
                # Concatenate rows for face_pose.csv
                face_pose_row = pose_row + face_row
                face_pose_row.insert(0, class_name)

                # Export to face_pose.csv
                with open('najlafaceneutre.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(face_pose_row) 

                # Extract Right Hand landmarks
                rh = results.right_hand_landmarks.landmark
                rh_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in rh]).flatten())
                
                # Extract Left Hand landmarks
                lh = results.left_hand_landmarks.landmark
                lh_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in lh]).flatten())
                
                # Concatenate rows for hands.csv
                hands_row = rh_row + lh_row
                hands_row.insert(0, class_name)

                # Export to hands.csv
                with open('najlahandsneutre.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(hands_row)

        except Exception as e:
            print(f"An error occurred: {e}")
        
        # Display the image
        cv2.imshow('Raw Webcam Feed', image)

        # Exit condition
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
#      57 with open('najlafaceneutre.csv', mode='a', newline='') as f:
#      58     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
# ---> 59     csv_writer.writerow(face_pose_row)
#      61 # Extract Right Hand landmarks
#      62 rh = results.right_hand_landmarks.landmark
#
# KeyboardInterrupt:
